# %%
import mlrose
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
fitness = mlrose.ContinuousPeaks(t_pct = .15)

# %%
problem = mlrose.DiscreteOpt(length = 90, fitness_fn = fitness, maximize = True, max_val = 2)

# %%
# Define decay schedule
schedule = mlrose.ExpDecay()

# Define initial state
# Solve problem using simulated annealing
start = time.time()
best_state, best_fitness, fitness_curve = mlrose.simulated_annealing(problem, schedule = schedule,
                                                      max_attempts = 10, max_iters = 1000,
                                                      random_state = 7,
                                                      curve=True)
end = time.time()
print('Elapsed Time: {} s'.format(end-start))

print(best_fitness)
# Out:
# Elapsed Time: 0.15485739707946777 s
# 34.0

# %%
plt.style.use('seaborn')

plt.figure()
plt.plot(fitness_curve)
plt.xlabel('iteration')
plt.ylabel('fitness')
plt.title('Fitness Curve for Randomized Optimization with Simulated Annealing: Continuous Peaks', fontsize = 18, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Fitness Curve for Randomized Optimization with Simulated Annealing: Continuous Peaks')

# %%
# Solve problem using random hill climb
start = time.time()
best_state, best_fitness, fitness_curve = mlrose.random_hill_climb(problem, restarts = 3,
                                                                  max_attempts = 10, max_iters = 1000,
                                                                  random_state = 42,
                                                                  curve=True)
end = time.time()
print('Elapsed Time: {} s'.format(end-start))

print(best_fitness)
# Out:
# Elapsed Time: 0.0043942928314208984 s
# 3.0

# %%
plt.style.use('seaborn')

plt.figure()
plt.plot(fitness_curve)
plt.xlabel('iteration')
plt.ylabel('fitness')
plt.title('Fitness Curve for Randomized Optimization with Random Hill Climb: Continuous Peaks', fontsize = 18, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Fitness Curve for Randomized Optimization with Random Hill Climb: Continuous Peaks')

# %%
# Solve problem using MIMIC
start = time.time()
best_state, best_fitness, fitness_curve = mlrose.mimic(problem, pop_size = 200, keep_pct = .2,
                                                        max_attempts = 10, max_iters = 1000,
                                                        random_state = 42,
                                                        curve=True)
end = time.time()
print('Elapsed Time: {} s'.format(end-start))

print(best_fitness)
# Out:
# Elapsed Time: 314.9447057247162 s
# 29.0

# %%
plt.style.use('seaborn')

plt.figure()
plt.plot(fitness_curve)
plt.xlabel('iteration')
plt.ylabel('fitness')
plt.title('Fitness Curve for Randomized Optimization with MIMIC: Continous Peaks', fontsize = 18, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Fitness Curve for Randomized Optimization with MIMIC: Continous Peaks')

# %%
# Solve problem using Genetic Algorithm
start = time.time()
best_state, best_fitness, fitness_curve = mlrose.genetic_alg(problem, mutation_prob=0.1,
                                                        max_attempts = 10, max_iters = 1000,
                                                        random_state = 42,
                                                        curve=True)
end = time.time()
print('Elapsed Time: {} s'.format(end-start))

print(best_fitness)
# Out:
# Elapsed Time: 0.5895459651947021 s
# 17.0

# %%
plt.style.use('seaborn')

plt.figure()
plt.plot(fitness_curve)
plt.xlabel('iteration')
plt.ylabel('fitness')
plt.title('Fitness Curve for Randomized Optimization with Genetic Algorithm: Continuous Peaks', fontsize = 18, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Fitness Curve for Randomized Optimization with Genetic Algorithm: Continuous Peaks')
